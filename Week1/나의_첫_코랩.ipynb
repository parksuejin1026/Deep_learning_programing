# %% [markdown]
# <a href="https://colab.research.google.com/github/parksuejin1026/Deep_learning_programing/blob/main/Week1/%EB%82%98%EC%9D%98_%EC%B2%AB_%EC%BD%94%EB%9E%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, DeepLearning!")
# Out:
# Hello, DeepLearning!

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# #모두의 딥러닝
# ##모두의 딥러닝
# ###모두의 딥러닝
